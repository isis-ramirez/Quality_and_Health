# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import scipy.stats as stat
# %matplotlib inline
import seaborn as sns

# %%
# calling and reading data and naming it iris_data
path=("C:/Users/isis1/OneDrive/Documents/combines_sets.csv")
combine = pd.read_csv(path)
#display first 5 rows of the data
combine.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0              263
# 1  Afghanistan  2014  Developing              59.9              271
# 2  Afghanistan  2013  Developing              59.9              268
# 3  Afghanistan  2012  Developing              59.5              272
# 4  Afghanistan  2011  Developing              59.2              275
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Population   thinness  1-19 years   thinness 5-9 years  \
# 0  33736494.0                   17.2                 17.3
# 1    327582.0                   17.5                 17.5
# 2  31731688.0                   17.7                 17.7
# 3   3696958.0                   17.9                 18.0
# 4   2978599.0                   18.2                 18.2
#
#    Income composition of resources  Schooling  \
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
#    National prevalence of diabates(%)   DTP  hipatitis B   polio_vaccines  \
# 0                                 6.3  74.0         59.33            70.0
# 1                                 6.3  74.0         59.33            70.0
# 2                                 6.3  74.0         59.33            70.0
# 3                                 6.3  74.0         59.33            70.0
# 4                                 6.3  74.0         59.33            70.0
#
#    measles
# 0     54.5
# 1     54.5
# 2     54.5
# 3     54.5
# 4     54.5
#
# [5 rows x 27 columns]

# %%
#reading the dataset types
print(combine.dtypes)
# Out:
# Country                                object
# Year                                    int64
# Status                                 object
# Life expectancy                       float64
# Adult Mortality                         int64
# infant deaths                           int64
# Alcohol                               float64
# percentage expenditure                float64
# Hepatitis B                           float64
# Measles                                 int64
#  BMI                                  float64
# under-five deaths                       int64
# Polio                                   int64
# Total expenditure                     float64
# Diphtheria                              int64
#  HIV/AIDS                             float64
# GDP                                   float64
# Population                            float64
#  thinness  1-19 years                 float64
#  thinness 5-9 years                   float64
# Income composition of resources       float64
# Schooling                             float64
# National prevalence of diabates(%)    float64
# DTP                                   float64
# hipatitis B                           float64
# polio_vaccines                        float64
# measles                               float64
# dtype: object

# %%
#statistical analysis of dataset attributes
print(combine.describe())
print(combine.describe(include="all"))
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count   270.000000        270.000000       270.000000     270.000000
# mean   2012.500000         72.392963       122.611111      50.511111
# std       1.710997          5.314593        71.121765     163.574494
# min    2010.000000         58.800000         6.000000       0.000000
# 25%    2011.000000         68.100000        67.250000       1.000000
# 50%    2012.500000         73.900000       125.000000       5.500000
# 75%    2014.000000         75.800000       179.000000      22.000000
# max    2015.000000         85.000000       294.000000    1200.000000
#
#           Alcohol  percentage expenditure  Hepatitis B      Measles   \
# count  227.000000              270.000000   264.000000    270.000000
# mean     1.883656              515.403904    88.549242   2995.955556
# std      2.446294             1241.183427    16.716987  10235.631503
# min      0.010000                0.000000     4.000000      0.000000
# 25%      0.010000                0.000000    84.000000      4.000000
# 50%      0.560000               65.268121    96.000000    100.000000
# 75%      2.775000              275.276795    98.000000    808.250000
# max     11.320000             9498.729062    99.000000  90387.000000
#
#              BMI   under-five deaths   ...    Population  \
# count  270.000000          270.000000  ...  1.920000e+02
# mean    37.477407           63.459259  ...  2.757458e+07
# std     19.819970          210.722188  ...  1.043158e+08
# min      2.100000            0.000000  ...  4.100000e+01
# 25%     19.650000            1.000000  ...  1.342535e+05
# 50%     37.300000            6.500000  ...  1.459045e+06
# 75%     55.275000           26.750000  ...  1.459763e+07
# max     71.400000         1600.000000  ...  1.293859e+09
#
#         thinness  1-19 years   thinness 5-9 years  \
# count             270.000000           270.000000
# mean                7.358519             7.549630
# std                 5.993099             5.984713
# min                 0.900000             1.000000
# 25%                 2.800000             3.100000
# 50%                 5.200000             5.100000
# 75%                11.075000            11.200000
# max                27.000000            27.800000
#
#        Income composition of resources   Schooling  \
# count                       270.000000  270.000000
# mean                          0.696989   12.513333
# std                           0.128971    1.880176
# min                           0.000000    7.500000
# 25%                           0.612250   11.425000
# 50%                           0.717500   12.700000
# 75%                           0.787000   13.700000
# max                           0.924000   16.100000
#
#        National prevalence of diabates(%)         DTP  hipatitis B   \
# count                          270.000000  270.000000    270.000000
# mean                             7.768889   89.881704     86.258889
# std                              4.172016   10.433898     13.392256
# min                              2.300000   10.500000      9.900000
# 25%                              5.000000   85.500000     77.000000
# 50%                              6.700000   93.500000     91.660000
# 75%                              8.700000   98.000000     96.330000
# max                             20.200000   99.000000     99.000000
#
#        polio_vaccines     measles
# count      270.000000  270.000000
# mean        86.503148   86.975222
# std         13.473441   13.333259
# min          9.550000   13.300000
# 25%         81.500000   82.000000
# 50%         92.500000   92.000000
# 75%         97.000000   96.500000
# max         99.000000   99.000000
#
# [8 rows x 25 columns]
#             Country         Year      Status  Life expectancy   \
# count           270   270.000000         270        270.000000
# unique           45          NaN           2               NaN
# top     Afghanistan          NaN  Developing               NaN
# freq              6          NaN         252               NaN
# mean            NaN  2012.500000         NaN         72.392963
# std             NaN     1.710997         NaN          5.314593
# min             NaN  2010.000000         NaN         58.800000
# 25%             NaN  2011.000000         NaN         68.100000
# 50%             NaN  2012.500000         NaN         73.900000
# 75%             NaN  2014.000000         NaN         75.800000
# max             NaN  2015.000000         NaN         85.000000
#
#         Adult Mortality  infant deaths     Alcohol  percentage expenditure  \
# count        270.000000     270.000000  227.000000              270.000000
# unique              NaN            NaN         NaN                     NaN
# top                 NaN            NaN         NaN                     NaN
# freq                NaN            NaN         NaN                     NaN
# mean         122.611111      50.511111    1.883656              515.403904
# std           71.121765     163.574494    2.446294             1241.183427
# min            6.000000       0.000000    0.010000                0.000000
# 25%           67.250000       1.000000    0.010000                0.000000
# 50%          125.000000       5.500000    0.560000               65.268121
# 75%          179.000000      22.000000    2.775000              275.276795
# max          294.000000    1200.000000   11.320000             9498.729062
#
#         Hepatitis B      Measles   ...    Population   thinness  1-19 years  \
# count    264.000000    270.000000  ...  1.920000e+02             270.000000
# unique          NaN           NaN  ...           NaN                    NaN
# top             NaN           NaN  ...           NaN                    NaN
# freq            NaN           NaN  ...           NaN                    NaN
# mean      88.549242   2995.955556  ...  2.757458e+07               7.358519
# std       16.716987  10235.631503  ...  1.043158e+08               5.993099
# min        4.000000      0.000000  ...  4.100000e+01               0.900000
# 25%       84.000000      4.000000  ...  1.342535e+05               2.800000
# 50%       96.000000    100.000000  ...  1.459045e+06               5.200000
# 75%       98.000000    808.250000  ...  1.459763e+07              11.075000
# max       99.000000  90387.000000  ...  1.293859e+09              27.000000
#
#          thinness 5-9 years  Income composition of resources   Schooling  \
# count            270.000000                       270.000000  270.000000
# unique                  NaN                              NaN         NaN
# top                     NaN                              NaN         NaN
# freq                    NaN                              NaN         NaN
# mean               7.549630                         0.696989   12.513333
# std                5.984713                         0.128971    1.880176
# min                1.000000                         0.000000    7.500000
# 25%                3.100000                         0.612250   11.425000
# 50%                5.100000                         0.717500   12.700000
# 75%               11.200000                         0.787000   13.700000
# max               27.800000                         0.924000   16.100000
#
#         National prevalence of diabates(%)         DTP  hipatitis B   \
# count                           270.000000  270.000000    270.000000
# unique                                 NaN         NaN           NaN
# top                                    NaN         NaN           NaN
# freq                                   NaN         NaN           NaN
# mean                              7.768889   89.881704     86.258889
# std                               4.172016   10.433898     13.392256
# min                               2.300000   10.500000      9.900000
# 25%                               5.000000   85.500000     77.000000
# 50%                               6.700000   93.500000     91.660000
# 75%                               8.700000   98.000000     96.330000
# max                              20.200000   99.000000     99.000000
#
#         polio_vaccines     measles
# count       270.000000  270.000000
# unique             NaN         NaN
# top                NaN         NaN
# freq               NaN         NaN
# mean         86.503148   86.975222
# std          13.473441   13.333259
# min           9.550000   13.300000
# 25%          81.500000   82.000000
# 50%          92.500000   92.000000
# 75%          97.000000   96.500000
# max          99.000000   99.000000
#
# [11 rows x 27 columns]

# %%
#finding null values
combine.isnull().sum()
# Out:
# Country                                0
# Year                                   0
# Status                                 0
# Life expectancy                        0
# Adult Mortality                        0
# infant deaths                          0
# Alcohol                               43
# percentage expenditure                 0
# Hepatitis B                            6
# Measles                                0
#  BMI                                   0
# under-five deaths                      0
# Polio                                  0
# Total expenditure                     44
# Diphtheria                             0
#  HIV/AIDS                              0
# GDP                                   36
# Population                            78
#  thinness  1-19 years                  0
#  thinness 5-9 years                    0
# Income composition of resources        0
# Schooling                              0
# National prevalence of diabates(%)     0
# DTP                                    0
# hipatitis B                            0
# polio_vaccines                         0
# measles                                0
# dtype: int64

# %%
#replacing missing values with mean value
mean_value=combine['GDP'].mean()
combine['GDP'].fillna(value=mean_value, inplace=True)
combine.head(20)
# Out:
#         Country  Year      Status  Life expectancy   Adult Mortality  \
# 0   Afghanistan  2015  Developing              65.0              263
# 1   Afghanistan  2014  Developing              59.9              271
# 2   Afghanistan  2013  Developing              59.9              268
# 3   Afghanistan  2012  Developing              59.5              272
# 4   Afghanistan  2011  Developing              59.2              275
# 5   Afghanistan  2010  Developing              58.8              279
# 6       Armenia  2015  Developing              74.8              118
# 7       Armenia  2014  Developing              74.6               12
# 8       Armenia  2013  Developing              74.4              123
# 9       Armenia  2012  Developing              74.4              121
# 10      Armenia  2011  Developing              73.9              128
# 11      Armenia  2010  Developing              73.5              132
# 12   Azerbaijan  2015  Developing              72.7              118
# 13   Azerbaijan  2014  Developing              72.5              119
# 14   Azerbaijan  2013  Developing              72.2              121
# 15   Azerbaijan  2012  Developing              71.9              123
# 16   Azerbaijan  2011  Developing              71.6              125
# 17   Azerbaijan  2010  Developing              71.1               13
# 18      Bahrain  2015  Developing              76.9               69
# 19      Bahrain  2014  Developing              76.8                7
#
#     infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0              62     0.01               71.279624         65.0      1154
# 1              64     0.01               73.523582         62.0       492
# 2              66     0.01               73.219243         64.0       430
# 3              69     0.01               78.184215         67.0      2787
# 4              71     0.01                7.097109         68.0      3013
# 5              74     0.01               79.679367         66.0      1989
# 6               1      NaN                0.000000         94.0        33
# 7               1     3.91              295.608714         93.0        13
# 8               1     3.79              279.429081         95.0        10
# 9               1     3.89              274.152699         95.0         0
# 10              1     4.09              260.996383         95.0         0
# 11              1     4.23              224.321201         94.0         2
# 12              5      NaN                0.000000         96.0         0
# 13              5     0.01              306.182431         94.0         0
# 14              5     2.14              275.651493         93.0       164
# 15              5     0.01              285.610391         88.0         0
# 16              5     1.98              263.142699         84.0         0
# 17              5     1.98              246.568601          8.0         0
# 18              0      NaN                0.000000         98.0         0
# 19              0     1.57              367.255674         98.0        46
#
#     ...  Population   thinness  1-19 years   thinness 5-9 years  \
# 0   ...  33736494.0                   17.2                 17.3
# 1   ...    327582.0                   17.5                 17.5
# 2   ...  31731688.0                   17.7                 17.7
# 3   ...   3696958.0                   17.9                 18.0
# 4   ...   2978599.0                   18.2                 18.2
# 5   ...   2883167.0                   18.4                 18.4
# 6   ...    291695.0                    2.1                  2.2
# 7   ...     29622.0                    2.1                  2.1
# 8   ...    289359.0                    2.1                  2.1
# 9   ...   2881922.0                    2.0                  2.1
# 10  ...   2875581.0                    2.0                  2.1
# 11  ...   2877311.0                    2.0                  2.1
# 12  ...   9649341.0                    2.8                  2.9
# 13  ...    953579.0                    2.8                  2.9
# 14  ...    941681.0                    2.8                  2.8
# 15  ...   9295784.0                    2.8                  2.8
# 16  ...    917382.0                    2.8                  2.9
# 17  ...    954332.0                    2.8                  2.9
# 18  ...         NaN                    6.2                  6.1
# 19  ...         NaN                    6.1                  6.0
#
#     Income composition of resources  Schooling  \
# 0                             0.479       10.1
# 1                             0.476       10.0
# 2                             0.470        9.9
# 3                             0.463        9.8
# 4                             0.454        9.5
# 5                             0.448        9.2
# 6                             0.741       12.7
# 7                             0.739       12.7
# 8                             0.736       12.7
# 9                             0.732       12.7
# 10                            0.729       12.7
# 11                            0.720       12.3
# 12                            0.758       12.7
# 13                            0.752       12.2
# 14                            0.745       11.9
# 15                            0.742       11.8
# 16                            0.741       11.7
# 17                            0.737       11.7
# 18                            0.823       14.5
# 19                            0.820       14.5
#
#     National prevalence of diabates(%)   DTP  hipatitis B   polio_vaccines  \
# 0                                  6.3  74.0         59.33           70.00
# 1                                  6.3  74.0         59.33           70.00
# 2                                  6.3  74.0         59.33           70.00
# 3                                  6.3  74.0         59.33           70.00
# 4                                  6.3  74.0         59.33           70.00
# 5                                  6.3  74.0         59.33           70.00
# 6                                  2.6  93.5         93.66           85.50
# 7                                  2.6  93.5         93.66           85.50
# 8                                  2.6  93.5         93.66           85.50
# 9                                  2.6  93.5         93.66           85.50
# 10                                 2.6  93.5         93.66           85.50
# 11                                 2.6  93.5         93.66           85.50
# 12                                 2.3  84.0         85.33           82.50
# 13                                 2.3  84.0         85.33           82.50
# 14                                 2.3  84.0         85.33           82.50
# 15                                 2.3  84.0         85.33           82.50
# 16                                 2.3  84.0         85.33           82.50
# 17                                 2.3  84.0         85.33           82.50
# 18                                17.3  98.0         98.66            9.55
# 19                                17.3  98.0         98.60           98.50
#
#     measles
# 0      54.5
# 1      54.5
# 2      54.5
# 3      54.5
# 4      54.5
# 5      54.5
# 6      94.0
# 7      94.0
# 8      94.0
# 9      94.0
# 10     94.0
# 11     94.0
# 12     80.5
# 13     80.5
# 14     80.5
# 15     80.5
# 16     80.5
# 17     80.5
# 18     99.0
# 19     99.0
#
# [20 rows x 27 columns]

# %%
#checking the GDP missing value count
combine.isnull().sum()
# Out:
# Country                                0
# Year                                   0
# Status                                 0
# Life expectancy                        0
# Adult Mortality                        0
# infant deaths                          0
# Alcohol                               43
# percentage expenditure                 0
# Hepatitis B                            6
# Measles                                0
#  BMI                                   0
# under-five deaths                      0
# Polio                                  0
# Total expenditure                     44
# Diphtheria                             0
#  HIV/AIDS                              0
# GDP                                    0
# Population                            78
#  thinness  1-19 years                  0
#  thinness 5-9 years                    0
# Income composition of resources        0
# Schooling                              0
# National prevalence of diabates(%)     0
# DTP                                    0
# hipatitis B                            0
# polio_vaccines                         0
# measles                                0
# dtype: int64

# %%
#replacing missing values with mean value for population
mean_value=combine['Population'].mean()
combine['Population'].fillna(value=mean_value, inplace=True)
#checking the population missing value count
combine.isnull().sum()
# Out:
# Country                                0
# Year                                   0
# Status                                 0
# Life expectancy                        0
# Adult Mortality                        0
# infant deaths                          0
# Alcohol                               43
# percentage expenditure                 0
# Hepatitis B                            6
# Measles                                0
#  BMI                                   0
# under-five deaths                      0
# Polio                                  0
# Total expenditure                     44
# Diphtheria                             0
#  HIV/AIDS                              0
# GDP                                    0
# Population                             0
#  thinness  1-19 years                  0
#  thinness 5-9 years                    0
# Income composition of resources        0
# Schooling                              0
# National prevalence of diabates(%)     0
# DTP                                    0
# hipatitis B                            0
# polio_vaccines                         0
# measles                                0
# dtype: int64

# %%
#deleting the columns we do not need
combine=combine.drop(combine.columns[[6,7,13,18,19]], axis=1)
#checking the population missing value count and the columns deleted
combine.isnull().sum()
# Out:
# Country                               0
# Year                                  0
# Status                                0
# Life expectancy                       0
# Adult Mortality                       0
# infant deaths                         0
# Hepatitis B                           6
# Measles                               0
#  BMI                                  0
# under-five deaths                     0
# Polio                                 0
# Diphtheria                            0
#  HIV/AIDS                             0
# GDP                                   0
# Population                            0
# Income composition of resources       0
# Schooling                             0
# National prevalence of diabates(%)    0
# DTP                                   0
# hipatitis B                           0
# polio_vaccines                        0
# measles                               0
# dtype: int64

# %%
#changing the "status" column to an integer type
combine['Status'] = combine['Status'].replace({'Developing':0,'Developed':1 })
combine['Status']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 265    0
# 266    0
# 267    0
# 268    0
# 269    0
# Name: Status, Length: 270, dtype: int64

# %%
#correlation between attributes
corr = combine.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_6b029_row0_col0, #T_6b029_row1_col1, #T_6b029_row2_col2, #T_6b029_row3_col3, #T_6b029_row4_col4, #T_6b029_row4_col8, #T_6b029_row5_col5, #T_6b029_row6_col6, #T_6b029_row7_col7, #T_6b029_row8_col4, #T_6b029_row8_col8, #T_6b029_row9_col9, #T_6b029_row10_col10, #T_6b029_row11_col11, #T_6b029_row12_col12, #T_6b029_row13_col13, #T_6b029_row14_col14, #T_6b029_row15_col15, #T_6b029_row16_col16, #T_6b029_row17_col17, #T_6b029_row18_col18, #T_6b029_row19_col19, #T_6b029_row20_col20 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6b029_row0_col1, #T_6b029_row10_col11, #T_6b029_row13_col17, #T_6b029_row20_col4 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_6b029_row0_col2, #T_6b029_row13_col3, #T_6b029_row16_col20 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_6b029_row0_col3, #T_6b029_row20_col16 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_6b029_row0_col4, #T_6b029_row0_col8 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_6b029_row0_col5, #T_6b029_row1_col9, #T_6b029_row13_col14, #T_6b029_row19_col7 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_6b029_row0_col6, #T_6b029_row0_col17, #T_6b029_row1_col3 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_6b029_row0_col7, #T_6b029_row6_col14, #T_6b029_row7_col17 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_6b029_row0_col9, #T_6b029_row6_col18, #T_6b029_row13_col18, #T_6b029_row18_col3, #T_6b029_row18_col11 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_6b029_row0_col10, #T_6b029_row1_col7, #T_6b029_row4_col2, #T_6b029_row8_col2, #T_6b029_row9_col3 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_6b029_row0_col11, #T_6b029_row4_col20, #T_6b029_row8_col20 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_6b029_row0_col12, #T_6b029_row6_col16 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_6b029_row0_col13, #T_6b029_row6_col9, #T_6b029_row6_col12, #T_6b029_row11_col5 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_6b029_row0_col14 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_6b029_row0_col15 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_6b029_row0_col16, #T_6b029_row3_col6, #T_6b029_row16_col8, #T_6b029_row20_col1 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_6b029_row0_col18 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_6b029_row0_col19, #T_6b029_row1_col4, #T_6b029_row4_col14, #T_6b029_row20_col8 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_6b029_row0_col20 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_6b029_row1_col0, #T_6b029_row3_col5, #T_6b029_row8_col7, #T_6b029_row12_col13, #T_6b029_row16_col0 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_6b029_row1_col2, #T_6b029_row4_col6 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_6b029_row1_col5, #T_6b029_row11_col8, #T_6b029_row18_col7 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_6b029_row1_col6, #T_6b029_row7_col8, #T_6b029_row14_col4, #T_6b029_row15_col11 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_6b029_row1_col8, #T_6b029_row8_col14, #T_6b029_row19_col4 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_6b029_row1_col10 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_6b029_row1_col11, #T_6b029_row6_col17 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_6b029_row1_col12 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_6b029_row1_col13, #T_6b029_row2_col6, #T_6b029_row18_col6 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_6b029_row1_col14 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_6b029_row1_col15, #T_6b029_row15_col7, #T_6b029_row15_col19 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_6b029_row1_col16, #T_6b029_row18_col16 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_6b029_row1_col17, #T_6b029_row1_col19, #T_6b029_row5_col7 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_6b029_row1_col18, #T_6b029_row3_col4, #T_6b029_row5_col12, #T_6b029_row8_col11, #T_6b029_row12_col18, #T_6b029_row20_col7 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_6b029_row1_col20, #T_6b029_row13_col11, #T_6b029_row16_col10, #T_6b029_row20_col12 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_6b029_row2_col0, #T_6b029_row4_col12, #T_6b029_row8_col12, #T_6b029_row18_col8 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_6b029_row2_col1, #T_6b029_row13_col4, #T_6b029_row14_col7 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_6b029_row2_col3, #T_6b029_row3_col1, #T_6b029_row3_col2, #T_6b029_row3_col9, #T_6b029_row3_col10, #T_6b029_row3_col12, #T_6b029_row3_col14, #T_6b029_row3_col15, #T_6b029_row3_col16, #T_6b029_row3_col17, #T_6b029_row3_col18, #T_6b029_row3_col19, #T_6b029_row3_col20, #T_6b029_row5_col4, #T_6b029_row5_col8, #T_6b029_row7_col6, #T_6b029_row8_col5, #T_6b029_row11_col0, #T_6b029_row11_col7, #T_6b029_row14_col11, #T_6b029_row15_col13, #T_6b029_row19_col13 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6b029_row2_col4, #T_6b029_row3_col0, #T_6b029_row11_col14 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_6b029_row2_col5, #T_6b029_row9_col14, #T_6b029_row9_col15, #T_6b029_row14_col16, #T_6b029_row17_col15 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_6b029_row2_col7, #T_6b029_row8_col13 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_6b029_row2_col8, #T_6b029_row4_col9, #T_6b029_row8_col9, #T_6b029_row14_col8 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_6b029_row2_col9, #T_6b029_row6_col13 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_6b029_row2_col10, #T_6b029_row12_col16, #T_6b029_row15_col17 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_6b029_row2_col11, #T_6b029_row8_col0, #T_6b029_row14_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_6b029_row2_col12, #T_6b029_row7_col16, #T_6b029_row14_col5 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_6b029_row2_col13, #T_6b029_row4_col5, #T_6b029_row7_col13, #T_6b029_row9_col13, #T_6b029_row18_col13 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_6b029_row2_col14, #T_6b029_row19_col17 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_6b029_row2_col15 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_6b029_row2_col16, #T_6b029_row13_col6, #T_6b029_row14_col10 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_6b029_row2_col17 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_6b029_row2_col18, #T_6b029_row10_col19, #T_6b029_row12_col14 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_6b029_row2_col19 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_6b029_row2_col20, #T_6b029_row5_col20 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_6b029_row3_col7, #T_6b029_row20_col13 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_6b029_row3_col8, #T_6b029_row16_col18, #T_6b029_row16_col19 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_6b029_row3_col11 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_6b029_row3_col13, #T_6b029_row10_col4, #T_6b029_row10_col8, #T_6b029_row15_col0 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_6b029_row4_col0, #T_6b029_row7_col11, #T_6b029_row18_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_6b029_row4_col1, #T_6b029_row11_col18 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_6b029_row4_col3, #T_6b029_row8_col3, #T_6b029_row12_col7 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_6b029_row4_col7, #T_6b029_row14_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_6b029_row4_col10, #T_6b029_row6_col7, #T_6b029_row8_col10, #T_6b029_row9_col6, #T_6b029_row15_col3, #T_6b029_row16_col11 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_6b029_row4_col11, #T_6b029_row17_col16 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_6b029_row4_col13, #T_6b029_row14_col9 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_6b029_row4_col15, #T_6b029_row8_col15 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_6b029_row4_col16, #T_6b029_row6_col20, #T_6b029_row8_col16, #T_6b029_row16_col4 {
#   bac

# %%
#Changing column names

orig_cols = list(combine.columns)
new_cols = []
for col in orig_cols:
    new_cols.append(col.strip().replace('  ', ' ').replace(' ', '_').replace('-', '_').lower())
    
combine.columns = new_cols
combine.head(2)
# Out:
#        country  year  status  life_expectancy  adult_mortality  infant_deaths  \
# 0  Afghanistan  2015       0             65.0              263             62
# 1  Afghanistan  2014       0             59.9              271             64
#
#    hepatitis_b  measles   bmi  under_five_deaths  ...  hiv/aids         gdp  \
# 0         65.0     1154  19.1                 83  ...       0.1  584.259210
# 1         62.0      492  18.6                 86  ...       0.1  612.696514
#
#    population  income_composition_of_resources  schooling  \
# 0  33736494.0                            0.479       10.1
# 1    327582.0                            0.476       10.0
#
#    national_prevalence_of_diabates(%)   dtp  hipatitis_b  polio_vaccines  \
# 0                                 6.3  74.0        59.33            70.0
# 1                                 6.3  74.0        59.33            70.0
#
#    measles
# 0     54.5
# 1     54.5
#
# [2 rows x 22 columns]

# %%
# Distribution of our life expectancy
sns.set(style='whitegrid')
f,ax = plt.subplots(1,1,figsize = (8,4))
ax = sns.distplot(combine['life_expectancy'], kde = True, color = 'c')
# Out:
# C:\Users\isis1\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, sharey=True, figsize=(15,5))
sns.regplot(x=combine['adult_mortality'], y=combine['gdp'], ax=ax1)
sns.regplot(x=combine['infant_deaths'], y=combine['gdp'], ax=ax2)
sns.regplot(x=combine['national_prevalence_of_diabates(%)'], y=combine['gdp'], ax=ax3)
# Out:
# <AxesSubplot:xlabel='national_prevalence_of_diabates(%)', ylabel='gdp'>

# %%
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, sharey=True, figsize=(15,5))
sns.regplot(x=combine['polio'], y=combine['schooling'], ax=ax1)
sns.regplot(x=combine['infant_deaths'], y=combine['schooling'], ax=ax2)
sns.regplot(x=combine['life_expectancy'], y=combine['schooling'], ax=ax3)
# Out:
# <AxesSubplot:xlabel='life_expectancy', ylabel='schooling'>

# %%
################################Multiple Linear Regression################################
X = combine[['schooling', 'gdp', 'polio',
       'national_prevalence_of_diabates(%)','income_composition_of_resources']]
y = combine['life_expectancy']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
coeff_df = pd.DataFrame(regressor.coef_, X.columns, columns=['Coefficient'])
coeff_df
# Out:
#                                     Coefficient
# schooling                              0.692087
# gdp                                    0.000047
# polio                                  0.025264
# national_prevalence_of_diabates(%)    -0.021785
# income_composition_of_resources       19.755174

# %%
y_pred = regressor.predict(X_test)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
# Out:
#      Actual  Predicted
# 64     73.9  73.652524
# 135    75.0  73.726717
# 153    67.8  74.238934
# 189    77.8  79.441676
# 253    69.2  71.852728
# 198    83.1  81.049944
# 144    78.5  72.907617
# 180    68.5  70.967996
# 256    68.5  71.342353
# 15     71.9  72.908194
# 244    65.6  70.556735
# 139    74.8  74.678638
# 124    69.4  71.017435
# 103    74.0  73.390400
# 8      74.4  73.335118
# 166    68.4  68.470543
# 45     67.4  67.601501
# 199    82.9  81.137857
# 59     79.5  76.870478
# 264    65.7  65.437388
# 176    66.0  65.144302
# 55     83.0  76.344955
# 7      74.6  73.376233
# 76     68.3  71.142235
# 252    69.4  72.090437
# 83     74.1  73.658136
# 190    77.5  78.403629
# 136    75.0  73.556238
# 188    77.9  75.958736
# 101    83.0  77.791623
# 96     83.7  79.822610
# 74     68.7  71.826132
# 261    75.6  71.746376
# 215    73.7  70.766008
# 227    73.9  72.957236
# 226    74.1  73.504849
# 92     82.1  80.054727
# 159    65.9  66.412620
# 219    68.8  69.620516
# 182    68.1  70.813790
# 116    74.5  76.639278
# 27     77.0  67.606778
# 154    67.3  73.924212
# 230    67.7  70.310670
# 236    75.2  75.065859
# 37     77.6  77.408863
# 187    78.1  79.848504
# 134    74.9  73.412152
# 20     76.7  75.727978
# 240    66.3  71.236891
# 181    68.4  70.856537
# 207    74.5  74.136306
# 206    74.6  74.305504
# 146    77.9  72.283983

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 2.2982853855096868
# Mean Squared Error: 9.48407263882368
# Root Mean Squared Error: 3.0796221584512082

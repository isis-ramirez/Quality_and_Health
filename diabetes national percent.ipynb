# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import scipy.stats as stat

# %%
##locating, reading, printing the csv file
path="C:/Users/isis1/OneDrive/Documents/np_diabetes.csv"
dataset=pd.read_csv(path)
dataset.head()
# Out:
#        Country  National prevalence of diabates(%)
# 0  Afghanistan                                 6.3
# 1      Armenia                                 2.6
# 2   Azerbaijan                                 2.3
# 3      Bahrain                                17.3
# 4   Bangladesh                                 5.5

# %%
##printing the type of attributes
print(dataset.dtypes)
# Out:
# Country                                object
# National prevalence of diabates(%)    float64
# dtype: object

# %%
## using the describe command to describe the dataset
print(dataset.describe(include="all"))
# Out:
#             Country  National prevalence of diabates(%)
# count            45                           45.000000
# unique           45                                 NaN
# top     Afghanistan                                 NaN
# freq              1                                 NaN
# mean            NaN                            7.768889
# std             NaN                            4.211339
# min             NaN                            2.300000
# 25%             NaN                            5.000000
# 50%             NaN                            6.700000
# 75%             NaN                            8.700000
# max             NaN                           20.200000

# %%
##locating missing values
dataset.isnull().sum()
# Out:
# Country                               0
# National prevalence of diabates(%)    0
# dtype: int64

# %%
## box plot to see where is the bulk of the data located
sb.boxplot(x=dataset['National prevalence of diabates(%)'])
# Out:
# <AxesSubplot:xlabel='National prevalence of diabates(%)'>

# %%
# National percentage of diabetes rages.
sb.displot(x='National prevalence of diabates(%)',kind ='hist', data= dataset, bins = 30, kde = True);

# %%
##Distribution of percentage by country.
dataset.plot(x="Country", y="National prevalence of diabates(%)",kind="bar")
plt.show()
